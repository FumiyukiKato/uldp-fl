# %% [markdown]
# # Personalized User-level DP

# %%
import numpy as np

import os
path_project = os.path.dirname(os.path.abspath('.'))
import sys
sys.path.append(os.path.join(path_project, 'src'))
sys.path.append(os.path.join(path_project, 'exp/script'))

img_path = os.path.join(path_project, 'exp', 'img')
pickle_path = os.path.join(path_project, 'exp', 'pickle')
results_path = os.path.join(path_project, 'exp', 'results')

from personalized_utils import (
    init_heart_disease_param,
    make_q_c_curve, plot_q_c_curve, 
    make_epsilon_u, group_by_closest_below,
    static_optimization, show_static_optimization_result,
    prepare_grid_search,
    run_online_optimization, show_online_optimization_result,
    run_with_specified_idx, show_specified_idx_result,
    plot_acc_results,
)
from mylogger import logger_set_warning, logger_set_info

# %% [markdown]
# # qC curve

# %% [markdown]
# Given following parameters, the q C pair satisfying the privacy constraint has many candidates
# - epsilon_u
# - delta
# - n_round
# - sigma

# %%
# Figure of q_c_pair.png
epsilon_u = 3.0
n_round = 20
delta = 1e-5
sigma = 0.5
x, y = make_q_c_curve(epsilon_u=epsilon_u, delta=delta, sigma=sigma, num_points=30, n_round=n_round, min=-6)
plot_q_c_curve(
    x, y,
    title=r"$\epsilon_u={}$, $\delta={}$, $\sigma={}$,  $T={}$".format(
                epsilon_u, delta, sigma, n_round,
            )
)
# Out:
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/q_c_pair-example.png

# %% [markdown]
# # PULDP-AVG

# %% [markdown]
# ## Offline HPO

# %% [markdown]
# ### HeartDisease

# %% [markdown]
# #### Parameters

# %% [markdown]
# #### Test with all of HPs for showing group-independency (Figure in Appendix)

# %% [markdown]
# Basic setting
#
# (This setup is close to the real world, and each group has a different number of users and different privacy budgets, so the optimal HP is likely to be different.)
#
# - (eps1, eps2, eps3) = (0.15, 3.0, 5.0)
# - with ratio (eps1, eps2, eps3) = (0.6, 0.25, 0.15)

# %%
logger_set_warning()
fed_sim_params = init_heart_disease_param(eps_u=0.5, parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.n_total_round = 30
fed_sim_params.times = 5
static_q_u_list = [1.0, 0.9, 0.8, 0.7, 0.5, 0.3, 0.1]

idx_per_group_list = prepare_grid_search(fed_sim_params.get_group_eps_set(), start_idx=0, end_idx=7)
static_optimization(fed_sim_params, idx_per_group_list, static_q_u_list=static_q_u_list, force_update=False)
min_idx, min_loss = show_static_optimization_result(
    fed_sim_params, idx_per_group_list, static_q_u_list=static_q_u_list,
    img_name=f"heart_disease-all"
)
print(f"min_idx = {min_idx}, min_loss = {min_loss}")
# Out:
# IDX:  {0.15: 0, 3.0: 0, 5.0: 0}
# ======== TIME: 0 start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp copy.ipynb Cell 12 line 1
#       <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=7'>8</a> static_q_u_list = [1.0, 0.9, 0.8, 0.7, 0.5, 0.3, 0.1]
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=9'>10</a> idx_per_group_list = prepare_grid_search(fed_sim_params.get_group_eps_set(), start_idx=0, end_idx=7)
# ---> <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=10'>11</a> static_optimization(fed_sim_params, idx_per_group_list, static_q_u_list=static_q_u_list, force_update=False)
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=11'>12</a> min_idx, min_loss = show_static_optimization_result(
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=12'>13</a>     fed_sim_params, idx_per_group_list, static_q_u_list=static_q_u_list,
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=13'>14</a>     img_name=f"heart_disease-all"
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=14'>15</a> )
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y105sZmlsZQ%3D%3D?line=15'>16</a> print(f"min_idx = {min_idx}, min_loss = {min_loss}")
#
# File ~/research/AcSilo/acsilo/src/personalized_utils.py:464, in static_optimization(fed_sim_params, idx_per_group_list, static_q_u_list, force_update)
#     462 for idx_per_group in idx_per_group_list:
#     463     print("IDX: ", idx_per_group)
# --> 464     result = fed_simulation(
#     465         fed_sim_params, idx_per_group=idx_per_group, static_q_u_list=static_q_u_list
#     466     )
#     467     q_u, C_u = result[0]["q_u"], result[0]["C_u"]
#     469     results_dict[str(idx_per_group)] = (q_u, C_u, result)
#
# File ~/research/AcSilo/acsilo/src/personalized_utils.py:359, in fed_simulation(fed_sim_params, idx_per_group, static_q_u_list)
#     357     print("======== TIME:", i, "start")
#     358     args.seed = args.seed + i
# --> 359     sim_results = run_simulation(
#     360         args,
#     361         path_project,
#     362         epsilon_list=fed_sim_params.epsilon_list,
#     363         ratio_list=fed_sim_params.ratio_list,
#     364         q_step_size=fed_sim_params.q_step_size,
#     365         idx_per_group=idx_per_group,
#     366         static_q_u_list=static_q_u_list,
#     367     )
#     368     results_list.append(sim_results)
#     369 return results_list
#
# File ~/research/AcSilo/acsilo/src/run_simulation.py:154, in run_simulation(args, path_project, data_seed, **kwargs)
#     113 else:
#     114     simulator = FLSimulator(
#     115         seed=base_seed,
#     116         model=model,
#    (...)
#     152         dynamic_global_learning_rate=args.dynamic_global_learning_rate,
#     153     )
# --> 154 simulator.run()
#     155 results = simulator.get_results()
#     156 return results
#
# File ~/research/AcSilo/acsilo/src/simulator.py:404, in FLSimulator.run(self)
#     401 received_results = 0
#     403 while received_results < expected_results:
# --> 404     silo_id, random_state, accountant_dct, result = output_queue.get()
#     405     if self.agg_strategy == METHOD_PULDP_AVG_ONLINE:
#     406         local_updated_weights_dct = result
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/multiprocessing/connection.py:221, in _ConnectionBase.recv_bytes(self, maxlength)
#     219 if maxlength is not None and maxlength < 0:
#     220     raise ValueError("negative maxlength")
# --> 221 buf = self._recv_bytes(maxlength)
#     222 if buf is None:
#     223     self._bad_message_length()
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/multiprocessing/connection.py:419, in Connection._recv_bytes(self, maxsize)
#     418 def _recv_bytes(self, maxsize=None):
# --> 419     buf = self._recv(4)
#     420     size, = struct.unpack("!i", buf.getvalue())
#     421     if size == -1:
#
# File ~/.pyenv/versions/3.9.2/lib/python3.9/multiprocessing/connection.py:384, in Connection._recv(self, size, read)
#     382 remaining = size
#     383 while remaining > 0:
# --> 384     chunk = read(handle, remaining)
#     385     n = len(chunk)
#     386     if n == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Various n_users with a single eps group (Fig in Sec4)

# %%
logger_set_warning()
fed_sim_params = init_heart_disease_param(eps_u=0.5, parallelized=True)

for n_users in [50, 100, 200, 400]:
    fed_sim_params.n_users = n_users
    idx_per_group_list = prepare_grid_search(fed_sim_params.get_group_eps_set(), start_idx=0, end_idx=12)
    static_optimization(fed_sim_params, idx_per_group_list, static_q_u_list=None, force_update=False)
    min_idx, min_loss = show_static_optimization_result(
        fed_sim_params, idx_per_group_list, 
        img_name=f"heart_disease-users-{n_users}"
    )
    print(min_idx, min_loss)
# Out:
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-users-50.png
# {0.5: 0} 0.5754557847976685
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-users-100.png
# {0.5: 2} 0.5067352712154388
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-users-200.png
# {0.5: 3} 0.49974275231361387
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-users-400.png
# {0.5: 5} 0.4715360403060913

# %% [markdown]
# #### Various eps_u with a single eps group (Fig in Sec4)

# %%
for eps_u in [0.15, 0.5, 1.0, 5.0]:
    fed_sim_params = init_heart_disease_param(eps_u=eps_u, parallelized=True)
    idx_per_group_list = prepare_grid_search(fed_sim_params.get_group_eps_set(), start_idx=0, end_idx=12)
    static_optimization(fed_sim_params, idx_per_group_list, static_q_u_list=None, force_update=False)
    min_idx, min_loss = show_static_optimization_result(
        fed_sim_params, idx_per_group_list, 
        img_name=f"heart_disease-uniform-eps-{eps_u}"
    )
    print(min_idx, min_loss)
# Out:
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-uniform-eps-0.15.png
# {0.15: 8} 0.5507778882980346
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-uniform-eps-0.5.png
# {0.5: 5} 0.4715360403060913
# IDX:  {1.0: 0}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 1}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 2}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 3}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 4}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 5}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 6}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 7}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 8}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 9}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 10}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# IDX:  {1.0: 11}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# Result objects saved to:  static_optimization_29d463ef4f8a6ae989a6c6917f239da8.pkl
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-uniform-eps-1.0.png
# {1.0: 3} 0.46369879245758056
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-uniform-eps-5.0.png
# {5.0: 0} 0.4719789981842041

# %% [markdown]
# #### for ULDP-AVG

# %%
static_q_u_list = [1.0, 0.9, 0.8, 0.7, 0.5, 0.3, 0.1, 0.07, 0.05, 0.01]
fed_sim_params = init_heart_disease_param(eps_u=0.15, parallelized=True)
idx_per_group_list = prepare_grid_search(fed_sim_params.get_group_eps_set(), start_idx=0, end_idx=10)
static_optimization(fed_sim_params, idx_per_group_list, static_q_u_list=static_q_u_list, force_update=False)
min_idx, min_loss = show_static_optimization_result(
    fed_sim_params, idx_per_group_list, 
    static_q_u_list=static_q_u_list,
    img_name=f"{fed_sim_params.dataset_name}-uldpavg",
)
print(f"min_idx = {min_idx}, min_loss = {min_loss}")
# Out:
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/static_optimization_result-1d-heart_disease-uldpavg.png
# min_idx = {0.15: 6}, min_loss = 0.5743536829948426

# %% [markdown]
# ## Online HPO

# %% [markdown]
# ### HeartDisease

# %% [markdown]
# #### QCTest

# %% [markdown]
# ##### different initial q_u

# %%
if "hd_all_acc_results" not in locals():
    hd_all_acc_results = {}
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTest"

initial_q_u_list = [0.1, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    fed_sim_params.initial_q_u = initial_q_u
    run_online_optimization(fed_sim_params, force_update=False)
    x, acc_means, acc_stds = show_online_optimization_result(
        fed_sim_params, errorbar=False,
        img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}"
    )
    hd_all_acc_results[(fed_sim_params.agg_strategy, initial_q_u)] = (x, acc_means, acc_stds)
# Out:
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-0.1.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-0.1.png
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-0.5.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-0.5.png
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-1.0.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-1.0.png

# %% [markdown]
# ##### different (bigger) step size

# %%
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTest"

initial_q_u_list = [0.1, 0.5, 1.0]
q_step_size_list = [0.3, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    for q_step_size in q_step_size_list:
        fed_sim_params.initial_q_u = initial_q_u
        fed_sim_params.q_step_size = q_step_size
        run_online_optimization(fed_sim_params, force_update=False)
        x, acc_means, acc_stds = show_online_optimization_result(
            fed_sim_params, errorbar=False,
            img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}-q_step_size{q_step_size}"
        )
# Out:
# ======== TIME: 0 start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp copy.ipynb Cell 25 line 1
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=13'>14</a> fed_sim_params.initial_q_u = initial_q_u
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=14'>15</a> fed_sim_params.q_step_size = q_step_size
# ---> <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=15'>16</a> run_online_optimization(fed_sim_params, force_update=False)
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=16'>17</a> x, acc_means, acc_stds = show_online_optimization_result(
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=17'>18</a>     fed_sim_params, errorbar=False,
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=18'>19</a>     img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}-q_step_size{q_step_size}"
#      <a href='vscode-notebook-cell:/Users/fumiyuki/research/AcSilo/acsilo/exp/puldp_exp%20copy.ipynb#Y124sZmlsZQ%3D%3D?line=19'>20</a> )
#
# File ~/research/AcSilo/acsilo/src/personalized_utils.py:970, in run_online_optimization(fed_sim_params, force_update)
#     967     print("Skip: File already exists.")
#     968     return
# --> 970 result = fed_simulation(fed_sim_params)
#     972 acc_mean, acc_std, loss_mean, loss_std = calc_metric(result)
#     973 print(
#     974     f"TEST ACC: {acc_mean:.4f} ± {acc_std:.4f}",
#     975     f", TEST LOSS: {loss_mean:.4f} ± {loss_std:.4f}",
#     976 )
#
# File ~/research/AcSilo/acsilo/src/personalized_utils.py:359, in fed_simulation(fed_sim_params, idx_per_group, static_q_u_list)
#     357     print("======== TIME:", i, "start")
#     358     args.seed = args.seed + i
# --> 359     sim_results = run_simulation(
#     360         args,
#     361         path_project,
#     362         epsilon_list=fed_sim_params.epsilon_list,
#     363         ratio_list=fed_sim_params.ratio_list,
#     364         q_step_size=fed_sim_params.q_step_size,
#     365         idx_per_group=idx_per_group,
#     366         static_q_u_list=static_q_u_list,
#     367     )
#     368     results_list.append(sim_results)
#     369 return results_list
#
# File ~/research/AcSilo/acsilo/src/run_simulation.py:114, in run_simulation(args, path_project, data_seed, **kwargs)
#      88     simulator = SecureWeightingFLSimulator(
#      89         seed=base_seed,
#      90         model=model,
#    (...)
#     111         sampling_rate_q=args.sampling_rate_q,
#     112     )
#     113 else:
# --> 114     simulator = FLSimulator(
#     115         seed=base_seed,
#     116         model=model,
#     117         train_dataset=train_dataset,
#     118         test_dataset=test_dataset,
#     119         local_dataset_per_silos=local_dataset_per_silos,
#     120         n_silos=args.n_silos,
#     121         n_users=args.n_users,
#     122         device=device,
#     123         n_total_round=args.n_total_round,
#     124         n_silo_per_round=args.n_silo_per_round,
#     125         local_learning_rate=args.local_learning_rate,
#     126         global_learning_rate=args.global_learning_rate,
#     127         local_batch_size=args.local_batch_size,
#     128         weight_decay=args.weight_decay,
#     129         client_optimizer=args.client_optimizer,
#     130         local_epochs=args.local_epochs,
#     131         agg_strategy=args.agg_strategy,
#     132         clipping_bound=args.clipping_bound,
#     133         sigma=args.sigma,
#     134         delta=args.delta,
#     135         group_k=args.group_k,
#     136         dataset_name=args.dataset_name,
#     137         sampling_rate_q=args.sampling_rate_q,
#     138         C_u=args.C_u,
#     139         q_u=args.q_u,
#     140         epsilon_u=args.epsilon_u,
#     141         group_thresholds=args.group_thresholds,
#     142         q_step_size=args.q_step_size,
#     143         validation_ratio=args.validation_ratio,
#     144         with_momentum=args.with_momentum,
#     145         off_train_loss_noise=args.off_train_loss_noise,
#     146         momentum_weight=args.momentum_weight,
#     147         hp_baseline=args.hp_baseline,
#     148         step_decay=args.step_decay,
#     149         initial_q_u=args.initial_q_u,
#     150         parallelized=args.parallelized,
#     151         gpu_id=args.gpu_id,
#     152         dynamic_global_learning_rate=args.dynamic_global_learning_rate,
#     153     )
#     154 simulator.run()
#     155 results = simulator.get_results()
#
# File ~/research/AcSilo/acsilo/src/simulator.py:91, in FLSimulator.__init__(self, seed, model, train_dataset, test_dataset, local_dataset_per_silos, n_silos, n_users, device, n_total_round, n_silo_per_round, local_learning_rate, global_learning_rate, local_batch_size, weight_decay, client_optimizer, local_epochs, agg_strategy, clipping_bound, sigma, delta, group_k, dataset_name, sampling_rate_q, C_u, q_u, epsilon_u, group_thresholds, q_step_size, validation_ratio, with_momentum, off_train_loss_noise, momentum_weight, hp_baseline, step_decay, initial_q_u, parallelized, gpu_id, dynamic_global_learning_rate)
#      89 self.device = device
#      90 self.gpu_id = gpu_id
# ---> 91 self.coordinator = Coordinator(
#      92     base_seed=seed,
#      93     n_silos=n_silos,
#      94     n_users=n_users,
#      95     group_k=group_k,
#      96     sampling_rate_q=sampling_rate_q,
#      97     agg_strategy=agg_strategy,
#      98     q_u=q_u,
#      99     epsilon_u=epsilon_u,
#     100     group_thresholds=group_thresholds,
#     101     delta=delta,
#     102     sigma=sigma,
#     103     n_total_round=n_total_round,
#     104     q_step_size=q_step_size,
#     105     step_decay=step_decay,
#     106     initial_q_u=initial_q_u,
#     107 )
#     109 self.aggregator = Aggregator(
#     110     model=copy.deepcopy(model),
#     111     train_dataset=train_dataset,
#    (...)
#     127     dynamic_global_learning_rate=dynamic_global_learning_rate,
#     128 )
#     130 if self.agg_strategy == METHOD_PULDP_AVG:
#
# File ~/research/AcSilo/acsilo/src/coordinator.py:76, in Coordinator.__init__(self, base_seed, n_silos, n_users, group_k, agg_strategy, sampling_rate_q, q_u, epsilon_u, group_thresholds, delta, sigma, n_total_round, q_step_size, hp_baseline, step_decay, initial_q_u)
#      74     INITIAL_Q_U = initial_q_u
#      75 for eps_u in self.epsilon_groups.keys():
# ---> 76     initial_C_u, _, _ = noise_utils.from_q_u(
#      77         q_u=INITIAL_Q_U,
#      78         delta=self.delta,
#      79         epsilon_u=eps_u,
#      80         sigma=self.sigma,
#      81         T=self.n_release,
#      82     )
#      83     self.hp_dct_by_eps[eps_u] = (INITIAL_Q_U, initial_C_u)
#      84     self.param_history[eps_u] = [(INITIAL_Q_U, initial_C_u)]
#
# File ~/research/AcSilo/acsilo/src/noise_utils.py:330, in from_q_u(q_u, delta, epsilon_u, sigma, T, alpha, precision)
#     328 else:
#     329     alpha_list = [alpha]
# --> 330 eps, best_alpha = accountant.get_privacy_spent(delta=delta, alphas=alpha_list)
#     331 if eps < epsilon_u:
#     332     min_sensitivity_u = sensitivity_u
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/rdp.py:55, in RDPAccountant.get_privacy_spent(self, delta, alphas)
#      52 if alphas is None:
#      53     alphas = self.DEFAULT_ALPHAS
#      54 rdp = sum(
# ---> 55     [
#      56         privacy_analysis.compute_rdp(
#      57             q=sample_rate,
#      58             noise_multiplier=noise_multiplier,
#      59             steps=num_steps,
#      60             orders=alphas,
#      61         )
#      62         for (noise_multiplier, sample_rate, num_steps) in self.history
#      63     ]
#      64 )
#      65 eps, best_alpha = privacy_analysis.get_privacy_spent(
#      66     orders=alphas, rdp=rdp, delta=delta
#      67 )
#      68 return float(eps), float(best_alpha)
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/rdp.py:56, in <listcomp>(.0)
#      52 if alphas is None:
#      53     alphas = self.DEFAULT_ALPHAS
#      54 rdp = sum(
#      55     [
# ---> 56         privacy_analysis.compute_rdp(
#      57             q=sample_rate,
#      58             noise_multiplier=noise_multiplier,
#      59             steps=num_steps,
#      60             orders=alphas,
#      61         )
#      62         for (noise_multiplier, sample_rate, num_steps) in self.history
#      63     ]
#      64 )
#      65 eps, best_alpha = privacy_analysis.get_privacy_spent(
#      66     orders=alphas, rdp=rdp, delta=delta
#      67 )
#      68 return float(eps), float(best_alpha)
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/analysis/rdp.py:284, in compute_rdp(q, noise_multiplier, steps, orders)
#     282     rdp = _compute_rdp(q, noise_multiplier, orders)
#     283 else:
# --> 284     rdp = np.array([_compute_rdp(q, noise_multiplier, order) for order in orders])
#     286 return rdp * steps
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/analysis/rdp.py:284, in <listcomp>(.0)
#     282     rdp = _compute_rdp(q, noise_multiplier, orders)
#     283 else:
# --> 284     rdp = np.array([_compute_rdp(q, noise_multiplier, order) for order in orders])
#     286 return rdp * steps
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/analysis/rdp.py:259, in _compute_rdp(q, sigma, alpha)
#     256 if np.isinf(alpha):
#     257     return np.inf
# --> 259 return _compute_log_a(q, sigma, alpha) / (alpha - 1)
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/analysis/rdp.py:217, in _compute_log_a(q, sigma, alpha)
#     215     return _compute_log_a_for_int_alpha(q, sigma, int(alpha))
#     216 else:
# --> 217     return _compute_log_a_for_frac_alpha(q, sigma, alpha)
#
# File ~/.pyenv/versions/3.9.2/envs/acsilo/lib/python3.9/site-packages/opacus/accountants/analysis/rdp.py:170, in _compute_log_a_for_frac_alpha(q, sigma, alpha)
#     168 coef = special.binom(alpha, i)
#     169 log_coef = math.log(abs(coef))
# --> 170 j = alpha - i
#     172 log_t0 = log_coef + i * math.log(q) + j * math.log(1 - q)
#     173 log_t1 = log_coef + j * math.log(q) + i * math.log(1 - q)
#
# KeyboardInterrupt:

# %% [markdown]
# ##### different momentum_weight

# %%
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTest"

initial_q_u_list = [0.1, 0.5, 1.0]
momentum_weight_list = [0.5, 0.9]
for initial_q_u in initial_q_u_list:
    for momentum_weight in momentum_weight_list:
        fed_sim_params.initial_q_u = initial_q_u
        fed_sim_params.momentum_weight = momentum_weight
        run_online_optimization(fed_sim_params, force_update=False)
        x, acc_means, acc_stds = show_online_optimization_result(
            fed_sim_params, errorbar=False,
            img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}-momentum{momentum_weight}"
        )
# Out:
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# TEST ACC: 0.7465 ± 0.0603 , TEST LOSS: 0.5170 ± 0.0511
# VALID ACC: 0.7669 ± 0.0676 , VALID LOSS: 0.5107 ± 0.0546
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-0.1.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-0.1.png
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# TEST ACC: 0.7559 ± 0.0305 , TEST LOSS: 0.4945 ± 0.0439
# VALID ACC: 0.7866 ± 0.0438 , VALID LOSS: 0.4849 ± 0.0446
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-0.5.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-0.5.png
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# TEST ACC: 0.7559 ± 0.0293 , TEST LOSS: 0.4928 ± 0.0440
# VALID ACC: 0.7921 ± 0.0389 , VALID LOSS: 0.4834 ± 0.0446
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-1.0.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-1.0.png
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# TEST ACC: 0.7331 ± 0.0778 , TEST LOSS: 0.5246 ± 0.0663
# VALID ACC: 0.7543 ± 0.0873 , VALID LOSS: 0.5192 ± 0.0668
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-0.1.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-0.1.png
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# TEST ACC: 0.7559 ± 0.0305 , TEST LOSS: 0.4942 ± 0.0434
# VALID ACC: 0.7882 ± 0.0436 , VALID LOSS: 0.4847 ± 0.0441
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-0.5.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-0.5.png
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# TEST ACC: 0.7559 ± 0.0293 , TEST LOSS: 0.4936 ± 0.0455
# VALID ACC: 0.7906 ± 0.0399 , VALID LOSS: 0.4842 ± 0.0461
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTest-1.0.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTest-1.0.png

# %% [markdown]
# #### QCTrain

# %% [markdown]
# ##### different initial q_u

# %%
if "hd_all_acc_results" not in locals():
    hd_all_acc_results = {}
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTrain"

initial_q_u_list = [0.1, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    fed_sim_params.initial_q_u = initial_q_u
    run_online_optimization(fed_sim_params, force_update=False)
    x, acc_means, acc_stds = show_online_optimization_result(
        fed_sim_params, errorbar=False,
        img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}"
    )
    hd_all_acc_results[(fed_sim_params.agg_strategy, initial_q_u)] = (x, acc_means, acc_stds)
# Out:
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-heart_disease-PULDP-AVG-QCTrain-0.1.png
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/online_optimization_result-losses-heart_disease-PULDP-AVG-QCTrain-0.1.png
# ======== TIME: 0 start
# ======== TIME: 1 start

# %% [markdown]
# ##### ablation study: weight decay

# %%
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTrain"
fed_sim_params.step_decay = False

initial_q_u_list = [0.1, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    fed_sim_params.initial_q_u = initial_q_u
    run_online_optimization(fed_sim_params, force_update=False)
    x, acc_means, acc_stds = show_online_optimization_result(
        fed_sim_params, errorbar=False,
        img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}-step_decay_off"
    )

# %% [markdown]
# ##### ablation study: momentum

# %%
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTrain"
fed_sim_params.with_momentum = False

initial_q_u_list = [0.1, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    fed_sim_params.initial_q_u = initial_q_u
    run_online_optimization(fed_sim_params, force_update=False)
    x, acc_means, acc_stds = show_online_optimization_result(
        fed_sim_params, errorbar=False,
        img_name=f"{fed_sim_params.dataset_name}-{fed_sim_params.agg_strategy}-{initial_q_u}-momentum_off"
    )

# %% [markdown]
# #### Baselines

# %% [markdown]
# ##### Best HP by static optimization (PULDP-AVG)
# $(\epsilon_1, \epsilon_2, \epsilon_3) => (q_u=0.1, q_u=0.7, q_u=1.0)$

# %%
if "hd_all_acc_results" not in locals():
    hd_all_acc_results = {}
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG"
static_q_u_list = [1.0, 0.9, 0.8, 0.7, 0.5, 0.3, 0.1]
best_idx_per_group = {0.15: 6, 3.0: 3, 5.0: 0}

run_with_specified_idx(
    fed_sim_params, best_idx_per_group, 
    static_q_u_list=static_q_u_list, force_update=False
)
x, acc_means, acc_stds = show_specified_idx_result(
    fed_sim_params, best_idx_per_group, static_q_u_list=static_q_u_list, errorbar=False,
    img_name=f"{fed_sim_params.dataset_name}-PULDPAVG"
)
hd_all_acc_results[(fed_sim_params.agg_strategy, "PULDP-AVG (Offline HPO)")] = (x, acc_means, acc_stds)
# Out:
# 02/08/2024 21:26:19:WARNING:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Skip: File already exists.
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/specified_idx_result-heart_disease-PULDPAVG.png

# %% [markdown]
# ##### random-updown

# %%
if "hd_all_acc_results" not in locals():
    hd_all_acc_results = {}

logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTrain"
fed_sim_params.step_decay = True
fed_sim_params.hp_baseline = "random-updown"

initial_q_u_list = [0.1, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    fed_sim_params.initial_q_u = initial_q_u
    run_online_optimization(fed_sim_params, force_update=False)
    x, acc_means, acc_stds = show_online_optimization_result(
        fed_sim_params, errorbar=False,
        img_name=f"{fed_sim_params.dataset_name}-{initial_q_u}-{fed_sim_params.hp_baseline}"
    )
    hd_all_acc_results[(fed_sim_params.hp_baseline, initial_q_u)] = (x, acc_means, acc_stds)
# Out:
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start

# %% [markdown]
# ##### Random

# %%
if "hd_all_acc_results" not in locals():
    hd_all_acc_results = {}

logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15, 3.0, 5.0]
fed_sim_params.group_thresholds = [0.15, 3.0, 5.0]
fed_sim_params.ratio_list = [0.6, 0.25, 0.15]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG-QCTrain"
fed_sim_params.step_decay = True
fed_sim_params.hp_baseline = "random"

initial_q_u_list = [0.1, 0.5, 1.0]
for initial_q_u in initial_q_u_list:
    fed_sim_params.initial_q_u = initial_q_u
    run_online_optimization(fed_sim_params, force_update=False)
    x, acc_means, acc_stds = show_online_optimization_result(
        fed_sim_params, errorbar=False,
        img_name=f"{fed_sim_params.dataset_name}-{initial_q_u}-{fed_sim_params.hp_baseline}"
    )
    hd_all_acc_results[(fed_sim_params.hp_baseline, "Random")] = (x, acc_means, acc_stds)

# %% [markdown]
# ##### ULDP-AVG

# %%
if "hd_all_acc_results" not in locals():
    hd_all_acc_results = {}
logger_set_warning()
fed_sim_params = init_heart_disease_param(parallelized=True)
fed_sim_params.epsilon_list = [0.15]
fed_sim_params.group_thresholds = [0.15]
fed_sim_params.ratio_list = [1.0]
fed_sim_params.validation_ratio = 0.5
fed_sim_params.times = 10
fed_sim_params.agg_strategy = "PULDP-AVG"
static_q_u_list = [1.0, 0.9, 0.8, 0.7, 0.5, 0.3, 0.1, 0.07, 0.05, 0.01]
best_idx_per_group = {0.15: 6}

run_with_specified_idx(
    fed_sim_params, best_idx_per_group, 
    static_q_u_list=static_q_u_list, force_update=False
)
x, acc_means, acc_stds = show_specified_idx_result(
    fed_sim_params, best_idx_per_group, static_q_u_list=static_q_u_list, errorbar=False,
    img_name=f"{fed_sim_params.dataset_name}-ULDPAVG"
)
hd_all_acc_results[(fed_sim_params.agg_strategy, "ULDP-AVG (Baseline)")] = (x, acc_means, acc_stds)
# Out:
# IDX:  {0.15: 6}
# ======== TIME: 0 start
# ======== TIME: 1 start
# ======== TIME: 2 start
# ======== TIME: 3 start
# ======== TIME: 4 start
# ======== TIME: 5 start
# ======== TIME: 6 start
# ======== TIME: 7 start
# ======== TIME: 8 start
# ======== TIME: 9 start
# 02/08/2024 21:26:00:WARNING:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# TEST ACC: 0.7244 ± 0.0347 , TEST LOSS: 0.5781 ± 0.0486
# VALID ACC: 0.7457 ± 0.0640 , VALID LOSS: 0.5612 ± 0.1040
# Result image saved to: /Users/fumiyuki/research/AcSilo/acsilo/exp/img/specified_idx_result-heart_disease-ULDPAVG.png

# %% [markdown]
# #### Compare all results

# %%
plot_acc_results(fed_sim_params, hd_all_acc_results, initial_q_u_list=[0.1, 0.5, 1.0], errorbar=False)
